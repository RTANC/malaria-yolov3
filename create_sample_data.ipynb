# %%
import glob
import random
import os
from shutil import copyfile, copy

# %%
f = open(os.path.join("data","custom","valid.txt"),"r")
files = list(f)
f.close()
for file in files:
    src = file.rstrip()
    print(src)
    copy(src, os.path.join("data","samples"))
# Out:
# data/custom/images/pv-test-0000000004.jpg
# data/custom/images/pv-test-0000000005.jpg
# data/custom/images/pv-test-0000000007.jpg
# data/custom/images/pv-test-0000000008.jpg
# data/custom/images/pv-test-0000000013.jpg
# data/custom/images/pv-test-0000000019.jpg
# data/custom/images/pv-test-0000000044.jpg
# data/custom/images/pv-test-0000000053.jpg
# data/custom/images/pv-test-0000000060.jpg
# data/custom/images/pv-test-0000000068.jpg
# data/custom/images/pv-test-0000000072.jpg
# data/custom/images/pv-test-0000000074.jpg
# data/custom/images/pv-test-0000000081.jpg
# data/custom/images/pv-test-0000000088.jpg
# data/custom/images/pv-test-0000000089.jpg
# data/custom/images/pv-test-0000000105.jpg
# data/custom/images/pv-test-0000000114.jpg
# data/custom/images/pv-test-0000000118.jpg
# data/custom/images/pv-test-0000000122.jpg
# data/custom/images/pv-test-0000000125.jpg
# data/custom/images/pv-test-0000000127.jpg
# data/custom/images/pv-test-0000000137.jpg
# ...
