# %%
import json
import numpy as np
from PIL import Image, ImageFont, ImageDraw, ImageEnhance
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from skimage.filters import threshold_otsu
from skimage.io import imread
from skimage.color import rgb2gray
from skimage.measure import label, regionprops
import json
import os
# import uuid
import random

# %%
labels = os.path.join('malaria','test.json')
count = 1
with open(labels,'r') as json_file:
    datas = json.load(json_file)
    for data in datas:
        img_name = data['image']['pathname']
        names = img_name.split('/')
        result = os.path.join('training_data',names[1],names[2])
        cmd = "copy " + result + " " + str(count) + ".jpg"
        os.system(cmd)
        objects = data['objects']
        count += 1
        print(result)
# Out:
# training_data/images/41be1bd3-0d31-4881-bf1f-3ccdfa21ff12.jpg
# training_data/images/64985a1e-16bb-4016-a01c-c21a5b86e572.jpg
# training_data/images/c70894fa-50e8-4eed-a5a8-159a20153a49.jpg
# training_data/images/abb72ce2-4193-4dd3-a34c-61c2ee22ccff.jpg
# training_data/images/8db76867-671a-4488-a7b6-991e4dd2e05f.jpg
# training_data/images/ebc4056e-d766-43cf-b6b4-5dac79d96e84.jpg
# training_data/images/d9ecacb0-14c7-4862-930b-18bb51d5f392.jpg
# training_data/images/96287315-87a1-4045-9e16-119e045bf12a.jpg
# training_data/images/37df4ffb-f268-4557-94d6-bf68d005feae.jpg
# training_data/images/8298aca0-5099-4d45-88ca-ec8ac7922e77.jpg
# training_data/images/a612e0d5-6a95-43cc-96a6-6fbcb8d45ff4.jpg
# training_data/images/a6e72060-5bde-490c-bdd7-7d9cb0fce7fc.jpg
# training_data/images/c11081a1-4fd9-4003-8bd9-0727eae62d0a.jpg
# training_data/images/738b7be5-59b5-4d8c-8769-cbf2385b9fc7.jpg
# training_data/images/51c6bc6b-4f37-4ce3-b624-840b27c1584a.jpg
# training_data/images/da2197c7-7911-4be6-8bb9-164f47fd270a.jpg
# training_data/images/23e581e7-0fb7-42ff-ba55-a86beefc0619.jpg
# training_data/images/54c88d45-30c3-46f8-8fef-b3e9c07781f2.jpg
# training_data/images/c3631a04-b757-407b-8e7e-1ed3a6c463d4.jpg
# training_data/images/8874ea02-d263-4830-99d1-e1b14230a56b.jpg
# training_data/images/31c62771-4e90-4038-9abc-d196beda9898.jpg
# training_data/images/c8d1b7ec-be9f-4c88-a39b-2c6bf46b2998.jpg
# training_data/images/96afe167-6a2f-4770-aa74-e083fbd5e926.jpg
# training_data/images/7d16d1e8-4abf-46fc-81bc-d71bd08ed6f2.jpg
# training_data/images/91fd0c2e-8e9c-452d-97ab-304b05a049b3.jpg
# training_data/images/511b6e13-acd7-4dd3-b1d0-c4aa10a514c7.jpg
# training_data/images/baab0701-3fd4-4940-8b90-b9c42d95888f.jpg
# training_data/images/3e03b313-66eb-471f-a97a-7b2bf20dcff5.jpg
# training_data/images/cc453255-b583-425e-bc3e-284ccf120944.jpg
# training_data/images/25865b39-56fb-409a-8800-3d368dd264ed.jpg
# training_data/images/78ae52cf-8dad-4070-a40e-9af02faec1f0.jpg
# training_data/images/f08e873b-9617-42b3-9c7a-55d0e39c2663.jpg
# training_data/images/8111cff9-4c04-448e-990b-9d5010f7be56.jpg
# training_data/images/e6a7743e-4040-40fa-b097-ca6874c469b7.jpg
# training_data/images/e02301ac-68f7-4daf-b2ba-254b917f1cca.jpg
# training_data/images/1e647046-333b-4102-a0c6-4c29405c37b3.jpg
# training_data/images/ef55f2ac-5a04-4986-99ab-0d2b5052ab3e.jpg
# training_data/images/a3548f89-1cb5-4e67-b460-482df95b10ee.jpg
# training_data/images/c6807595-100a-4aa1-a5f6-882a20ca3d32.jpg
# training_data/images/34f334e6-a163-4af7-a1ed-51a7ef15934a.jpg
# training_data/images/4dcd5df9-c56c-471b-8d44-fa4b1ca9a600.jpg
# training_data/images/bfbf234a-cbc4-4d00-ab7f-9043d1304b41.jpg
# training_data/images/a4bd99a0-226a-4044-914b-8073d5890734.jpg
# training_data/images/74bf1267-d98b-4532-a81d-9d8df63e0f75.jpg
# training_data/images/6d9a2241-2cce-42b3-a11d-a3a6b432dd89.jpg
# training_data/images/5bfde411-aa51-45d0-8b67-a57c5f1e628b.jpg
# training_data/images/6040cf0d-9dd6-4798-9406-1afbbcd24d4c.jpg
# training_data/images/408745a6-79fb-4804-9c24-e2d6673f8f2e.jpg
# training_data/images/010961af-b38c-49de-aca0-e3732d73d414.jpg
# training_data/images/47112c6b-aaf6-488d-8f3b-f9ed0cce9a95.jpg
# training_data/images/b1d312cf-1f52-4955-bf42-58d3664c254a.jpg
# training_data/images/5c399ab9-492c-4bfc-a452-83aba574a3bc.jpg
# training_data/images/96957ec3-de17-41cf-855b-1388814e5918.jpg
# training_data/images/291fe50c-2134-4708-bfa4-09b36ffea123.jpg
# training_data/images/9cf3f75a-354c-46f9-8b53-0a9711ac8bee.jpg
# training_data/images/efb85f8e-c780-4a19-b6ce-555a154b0d10.jpg
# training_data/images/bd4da4f8-8996-47e0-a4e5-a3da5717441e.jpg
# training_data/images/ebb53337-1d4f-4ab5-9b6d-83a66f48fe2e.jpg
# training_data/images/3ce76f1d-636a-48b9-b0e3-fc7eb791a169.jpg
# training_data/images/dea9006d-c360-4118-b77b-8bc959fa5f8a.jpg
# training_data/images/6e20a860-1f9a-4a74-b167-4c6a79bd8778.jpg
# training_data/images/0a3b53c7-e7ab-4135-80aa-fd2079d727d6.jpg
# training_data/images/4da8f6c5-5f85-4280-92d0-1ba008e8c404.jpg
# training_data/images/b47c1011-0cc6-400d-9300-1c72f873a6e5.jpg
# training_data/images/623982a0-1f73-4246-92cb-28f7c219efaf.jpg
# training_data/images/c328260d-bafa-4aaa-9e7a-79bc165d7fdb.jpg
# training_data/images/21116b9d-e6be-483f-8394-e74622b2e182.jpg
# training_data/images/e93e617e-ed36-43d9-bd1a-4ffd2fba64e9.jpg
# training_data/images/3147f1e4-6fc4-4eff-a9dd-ddeee5e2de13.jpg
# training_data/images/e26b88c6-5884-4b5c-94d7-ad780379c8ad.jpg
# training_data/images/1b814efc-7bf9-40ae-8e13-49dc2c04732f.jpg
# training_data/images/693da701-2020-404c-866d-b64c12da951d.jpg
# training_data/images/b6fe541f-3be2-41a8-8124-757fc1ad875e.jpg
# training_data/images/887cc81a-bae3-4360-a115-23ae05ac3a4f.jpg

# %%
labels = os.path.join('malaria','test.json')
count = 1
countP = 0
with open(labels,'r') as json_file:
    datas = json.load(json_file)
    for data in datas:
        img_name = data['image']['pathname']
        names = img_name.split('/')
        result = os.path.join('malaria',names[1],names[2])
        img = Image.open(result)
        objects = data['objects']
        for obj in objects:
            minr = obj['bounding_box']['minimum']['r']
            minc = obj['bounding_box']['minimum']['c']
            maxr = obj['bounding_box']['maximum']['r']
            maxc = obj['bounding_box']['maximum']['c']
            category = obj['category']
            if category == "ring" or category == "trophozoite" or category == "schizont" or category == "gametocyte":
                draw = ImageDraw.Draw(img)
                draw.rectangle((minc, minr,maxc,maxr), fill=None,outline="red",width=5)
                countP = countP + 1
        save_path = os.path.join('test_img',str(count)+ "-label" + ".jpg")
        img.save(save_path)
        count += 1
#         break

# %%
print(countP)
# Out:
# 303
